# %%
import pandas as pd

# 데이터 로드
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# 결측값 처리
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna('S', inplace=True)

print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# /var/folders/nl/5tltl7wj45d9l8y55cmc_8900000gn/T/ipykernel_38767/709690339.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# /var/folders/nl/5tltl7wj45d9l8y55cmc_8900000gn/T/ipykernel_38767/709690339.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('S', inplace=True)

# %%
# 생존자 수
print(df['Survived'].value_counts())

# 성별에 따른 생존율
survival_rate_by_gender = df.groupby('Sex')['Survived'].mean()
print(survival_rate_by_gender)
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
import matplotlib.pyplot as plt

# 생존자 시각화
survival_counts = df['Survived'].value_counts()
plt.bar(['Not Survived', 'Survived'], survival_counts, color=['red', 'green'])
plt.title('Survival Count')
plt.show()

# 성별 생존율 시각화
plt.bar(survival_rate_by_gender.index, survival_rate_by_gender, color=['blue', 'orange'])
plt.title('Survival Rate by Gender')
plt.show()
